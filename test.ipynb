# %%
with open("files_practice/numbers.txt", "r") as file:
    numbers = file.read()
    
with open("files_practice/numbers.txt", "r") as file:
    num_lines = file.readlines()
print(numbers)
print(num_lines)

# %%
import os 
import random as r

# %%
def get_image(folder):
    images = 
    return images

# %%
def balance(folder):
    images = os.listdir(folder)          #get all images 
    for i in range(len(images)//2):      #loop half times of images 
        to_remove = r.choice(images)     #random choice 
        os.remove(folder+'/'+to_remove)              #remove it
        images = os.listdir(folder)        #get rest of images     
        print(f"{to_remove} is destroyed")
    print("Thanos: the universe is balanced")

# %%
balance ("universe")

# %%
#######################################################################################

# %%
import numpy as np
